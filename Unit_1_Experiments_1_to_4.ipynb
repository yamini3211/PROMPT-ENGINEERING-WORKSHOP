# %%
 #install google gemini generative ai librarries

# %%
# %pip install -U -q "google-generativeai>=0.7.2"

# %%
# !pip install openai  google-generativeai transformers torch langchain

# %%
import google.generativeai as genai
from IPython.display import Markdown
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('apikey1')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
#unit 1-experment1:generate apikey in openAI and Google GeminiAI

# %%
import google.generativeai as genai

model = genai.GenerativeModel("gemini-3.5-flash")

response = model.generate_content(
    "Hello World"
)

print(response.text)
# Out:
# Hello, World! How can I help you today?

# %%
from google.colab import userdata
from google import genai
client = genai.Client(api_key=GOOGLE_API_KEY)
for model in client.models.list():
    if "gemini" in model.name.lower():
        print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# ...

# %%
#experiment2
#baseline prompt against enhanced prompt

# %%
print("BASELINE")
response=client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Write a one-paragraph bio of Ada Lovelace."
)

print(response.text)
# Out:
# BASELINE
# Ada Lovelace (1815–1852) was an English mathematician and writer who is widely celebrated today as the world’s first computer programmer. The daughter of the infamous Romantic poet Lord Byron and the mathematically gifted Annabella Milbanke, Lovelace was raised on a strict academic regimen of science and logic. This unique upbringing paved the way for her historic collaboration with inventor Charles Babbage on his Analytical Engine, a precursor to the modern computer. While translating an Italian article about the machine in 1843, Lovelace appended her own extensive notes, which included the first published algorithm designed to be carried out by a machine. Remarkably, her concept of "poetical science" allowed her to foresee that computers could go beyond mere calculation to manipulate symbols, predicting their future capability to create music, art, and scientific models.

# %%
print("\nENHANCED")

prompt="""
You are a Computer Science Professor.
Write a biography of Ada Lovelace.
Include
Early Life
Major Contributions
Achievements
Impact on Computing
Limit 200 words
Use Markdown headings.
"""
response=client.models.generate_content(model="gemini-3.5-flash", contents=prompt)
print(response.text)
# Out:
# ENHANCED
# ### Early Life
# Born in 1815 to the poet Lord Byron and Lady Byron, Ada was steered toward mathematics by her mother to counter her father’s artistic "madness." Tutored by Mary Somerville, she developed a passion for "poetical science," blending logic with imagination.
#
# ### Major Contributions
# Collaborating with Charles Babbage on his proposed Analytical Engine, Lovelace translated an article on the machine by Luigi Menabrea. In her extensive "Notes" (1843), she appended the first published algorithm—a method for the engine to calculate Bernoulli numbers.
#
# ### Achievements
# Lovelace is recognized as the world's first computer programmer. Crucially, she realized the Engine could manipulate symbols beyond mere numbers, predicting it could compose music and generate graphics, transcending simple calculation.
#
# ### Impact on Computing
# ...

# %%
#experiment 3-iterative refinement on a Simple Task:
#summarize the plot of the Shakespearean play romeo and juliet in two sentences through three rounds of prompt twakeing

# %%
from google import genai

# Replace with your Gemini API Key
API_KEY = "AQ.Ab8RN6JzEdBMraoDj4EE-zxyTbKwKYGCfmlG-IH2ywSUDHRJ4w"

# Create client
client = genai.Client(api_key="AQ.Ab8RN6JzEdBMraoDj4EE-zxyTbKwKYGCfmlG-IH2ywSUDHRJ4w")

# List of prompts
prompts = [
    # Iteration 1
    "Summarize the plot of Shakespeare's play Romeo and Juliet in two sentences.",

    # Iteration 2
    "Summarize the plot of Shakespeare's play Romeo and Juliet in exactly two concise and formal sentences suitable for high school literature students.",

    # Iteration 3
    "Summarize the plot of Shakespeare's play Romeo and Juliet in exactly two formal sentences. Include the setting (Verona, Italy) and emphasize the themes of love, fate, and family conflict."
]

# Generate responses
for i, prompt in enumerate(prompts, start=1):
    print("=" * 70)
    print(f"Iteration {i}")
    print("=" * 70)
    print("\nPrompt:")
    print(prompt)

    response = client.models.generate_content(
        model="gemini-3.5-flash",
        contents=prompt
    )

    print("\nGenerated Summary:")
    print(response.text)
    print("\n")
# Out:
# ...
# Iteration 1
# ...
#
# Prompt:
# Summarize the plot of Shakespeare's play Romeo and Juliet in two sentences.
#
# Generated Summary:
# Against the backdrop of a bitter feud between the Capulet and Montague families in Verona, Romeo and Juliet fall deeply in love and marry in secret. Ultimately, a series of tragic misunderstandings leads the young lovers to take their own lives, a devastating sacrifice that finally forces their grieving families to reconcile.
#
#
# ...
# Iteration 2
# ...
#
# Prompt:
# Summarize the plot of Shakespeare's play Romeo and Juliet in exactly two concise and formal sentences suitable for high school literature students.
#
# Generated Summary:
# Set in Verona, this classic tragedy follows Romeo Montague and Juliet Capulet, two young lovers who defy their families' ancient feud to marry in secret. Tragically, a series of fateful misunderstandings leads to their untimely double suicide, an event that ultimately reconciles their grieving households.
#
#
# ...
# Iteration 3
# ...
#
# Prompt:
# ...

# %%
# EXPERIMENT-4:Working with Vague prompt,Contradictory prompt,Refined prompt and diagnoising

# %%
from google import genai
from IPython.display import Markdown

# Ensure API_KEY is defined. If you intend to use GOOGLE_API_KEY from userdata,
# please ensure the cell defining GOOGLE_API_KEY (e.g., 81xord4c1NeY) is run first.
# For now, using API_KEY which is defined in a previous cell (rUL5aLQAUvBF).
client = genai.Client(api_key="AQ.Ab8RN6JzEdBMraoDj4EE-zxyTbKwKYGCfmlG-IH2ywSUDHRJ4w")

prompts = [
    {
        "title": "1. Vague Prompt",
        "prompt": "Tell me about Python."
    },
    {
        "title": "2. Contradictory Prompt",
        "prompt": "Explain Python in one sentence and provide a detailed explanation with examples."
    },
    {
        "title": "3. Refined Prompt",
        "prompt": """
Explain Python programming for beginners.

Instructions:
- Write exactly five bullet points.
- Use simple, easy-to-understand language.
- Highlight its main applications.
- Provide a brief example of a common Python use case.
"""
    }
]

# Generate responses
for i, item in enumerate(prompts, start=1):
    print("=" * 70)
    print(f"Prompt Iteration {i}: {item['title']}")
    print("=" * 70)
    print("\nPrompt:")
    print(item["prompt"])

    response = client.models.generate_content(
        model="gemini-3.5-flash", # Updated to the recommended model
        contents=item["prompt"]
    )

    print("\nGenerated Response:")
    print(response.text)
    print("\n")
# Out:
# ...
# Prompt Iteration 1: 1. Vague Prompt
# ...
#
# Prompt:
# Tell me about Python.
#
# Generated Response:
# **Python** is one of the most popular, versatile, and beginner-friendly programming languages in the world today. Created by **Guido van Rossum** and first released in **1991**, Python was designed with a core philosophy: **readability and simplicity.**
#
# Here is a comprehensive guide to what Python is, why it is so popular, what it is used for, and its pros and cons.
#
# ---
#
# ### 1. Key Features of Python
#
# *   **Easy-to-Read Syntax:** Python code looks a lot like plain English. It uses indentation (whitespace) to define blocks of code, rather than the curly braces `{}` or semicolons `;` used by languages like C++ or Java.
# *   **Interpreted Language:** Python code is executed line-by-line, which makes debugging easier and allows for rapid prototyping.
# ...
